# %%
import pandas as pd
import pymc3 as pm
import matplotlib.pyplot as plt
import arviz as az
import numpy as np

# %%
# getting the pandas dataframe from the csv file

df = pd.read_csv(r'prices.csv')
print(df)
# Out:
#      Price  Speed  HardDrive  Ram Premium
# 0     1499     66        540    8     yes
# 1     2190     33        426    8     yes
# 2     2745     66       1600   24     yes
# 3     2744     50        420    8     yes
# 4     1849     33        212    4      no
# ..     ...    ...        ...  ...     ...
# 495   1790     66        730    8     yes
# 496   2295     33        245    8     yes
# 497   1690     33        107    2     yes
# 498   2154     66       1000   16     yes
# 499   2090     66        214    4     yes
#
# [500 rows x 5 columns]

# %%
# we will extract x1 as being "Speed" and x2 as being ln("Ram")

# getting ln of ram
df['HardDrive'] = np.log(df['HardDrive'])

X = df[["Speed", "HardDrive"]].to_numpy()
# print(X)
# we obtain the mean for x1 and x2 respectively
X_mean = np.mean(X, axis=0, keepdims=True)
print(X_mean)
X_centered = np.subtract(X, X_mean)
# print(X_centered)
# Out:
# [[52.004     5.877261]]

# %%
# now we will get y as a numpy array
y = df["Price"].to_numpy()
print(y)
# Out:
# [1499 2190 2745 2744 1849 2989 2595 2744 2799 2565 1599 2144 2794 1995
#  2609 2444 2790 2595 2344 1290 2195 2444 2444 1940 3344 1890 1899 2390
#  3695 1999 2995 3299 2159 2804 2723 2895 1904 2590 1559 2344 1999 2190
#  2294 1890 1540 1999 2844 2769 2069 1288 1590 1788 2559 2575 2149 1599
#  1490 2699 3015 2190 2059 2290 1995 2499 2344 2520 2120 1695 1790 1399
#  2999 3044 1990 2290 2465 2225 2690 2490 2899 2795 1395 1295 2095 2090
#  2099 1490 3144 1490 1295 2795 2545 2149 1990 3090 2140 2854 2944 1689
#  2473 1279 1399 1295 2690 2594 3048 1354 2623 2145 2690 1398 1489 1995
#  2079 1599 1723 2995 4195 1854 1795 2240 3148 2094 2443 1599 1395 2390
#  3094 2935 1690 2095 2744 2849 2344 2844 1398 2625 2328 3149 2643 2690
#  1795 2220 2075 1520 2165 1999 2040 1440 2775 1544 2744 2575 3044 2390
#  1844 1995 2705 2490 1890 1299 2390 1299 3140 1548 1499 2590 2395 2295
#  2145 3048 1945 1989 2745 3090 1795 2108 2099 2220 1994 2204 2999 1268
#  3144 2795 1740 1709 2444 1973 1799 2545 1699 1844 2744 2345 2374 1744
#  1790 2590 1899 1795 2894 3194 2795 1349 2993 2794 2295 1690 1775 2955
#  2175 1945 1595 2254 3095 1898 2373 2575 3714 1644 1765 1499 1779 2599
#  3995 2604 1744 1588 3094 3379 1675 1744 2744 3694 1345 1694 2944 2194
#  1468 2090 2290 3035 1595 1395 2390 1719 1468 1744 2744 2940 1982 1449
#  2208 2339 2094 1259 1490 1824 2644 1499 2790 1799 3485 1544 2690 1799
#  2129 2645 2790 2444 2599 2095 3795 1899 2590 2195 2890 2643 2195 1891
#  1199 2473 1990 1890 2595 2095 2189 2239 1490 1795 2545 2344 3019 2195
#  2819 2995 2144 2118 1695 2090 2840 2744 2244 2290 2399 1499 1844 1865
#  1645 3928 2873 2627 1995 2035 1744 2015 1349 1599 2244 2929 2304 2144
#  2595 1799 1390 2394 3928 2554 2744 2090 2899 2899 2090 2999 2225 2189
#  1999 1899 3205 2159 1544 1448 4999 2095 1995 1948 2125 2344 1908 2694
#  1799 1288 3145 2544 2245 1749 1754 2444 2943 1854 2258 2699 2065 1944
#  1999 1945 1690 1645 1590 1998 2994 2349 1595 1490 2620 2409 1990 1449
#  1745 1788 2449 1749 2834 2018 3144 2295 1195 2049 1599 2490 2290 2943
#  2035 2995 1749 1999 1694 1995 2295 1695 2395 1639 2294 2599 1944 2290
#  1944 1795 1590 1399 2004 1994 2090 2554 2575 2627 3094 2890 3789 2729
#  1849 2185 1795 1923 2895 2718 2915 2099 1590 2890 2238 1699 3044 2499
#  1644 1795 2999 1995 2345 1519 1574 1944 2599 2595 1999 2044 2093 2499
#  2144 1823 2688 2595 2090 2189 2395 1895 1895 2499 2225 2999 1490 2543
#  1995 2093 2590 1995 2129 2795 1890 1790 1344 1823 1615 2695 2490 3948
#  2320 1970 2804 2990 2499 2320 2690 2190 1805 2189 2690 2744 1545 2444
#  2575 1795 2569 2095 2145 1790 2295 1690 2154 2090]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(df['Speed'], df['HardDrive'], df['Price'])
plt.show()

# %%
with pm.Model() as model_mlr:
    α_tmp = pm.Normal('α_tmp', mu=0, sd=10)
    β = pm.Normal('β', mu=0, sd=1, shape=2)
    ε = pm.HalfCauchy('ε', 5)
    μ = α_tmp + pm.math.dot(X_centered, β)
    α = pm.Deterministic('α', α_tmp - pm.math.dot(X_mean, β))
    y_pred = pm.Normal('y_pred', mu=μ, sd=ε, observed=y)
    idata_mlr = pm.sample(1000, return_inferencedata=True, init='map')
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using map...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='49' class='' max='49' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [49/49 00:00&lt;00:00 logp = -4,601.3, ||grad|| = 33.27]
#     </div>
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [ε, β, α_tmp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:05&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 6 seconds.

# %%
az.plot_trace(idata_mlr, var_names=['β'])
# Out:
# array([[<AxesSubplot:title={'center':'β'}>,
#         <AxesSubplot:title={'center':'β'}>]], dtype=object)

# %%
az.summary(idata_mlr, var_names=['β'], hdi_prob=0.90, stat_funcs=None)
# Out:
#        mean     sd  hdi_5%  hdi_95%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# β[0]  0.278  1.011  -1.447    1.904      0.023    0.019    1886.0    2179.0
# β[1]  0.020  1.029  -1.619    1.682      0.025    0.020    1687.0    1728.0
#
#       r_hat
# β[0]    1.0
# β[1]    1.0

# %% [markdown]
# Conform datelor obtinute exista o dependenta liniara dintre frecvenţa procesorului şi marimea hard diskului. Astfel, ei sunt niste predictori utili ai pretului de vânzare.

# %%
with model_mlr:
    data = pm.sample(50000, return_inferencedata=True, init='map')
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using map...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='49' class='' max='49' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [49/49 00:00&lt;00:00 logp = -4,601.3, ||grad|| = 33.27]
#     </div>
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [ε, β, α_tmp]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='204000' class='' max='204000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [204000/204000 02:08&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 50_000 draw iterations (4_000 + 200_000 draws total) took 128 seconds.
